# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
url = 'https://www.tu-chemnitz.de/informatik/TI/sonstiges/veranstaltungen.php'
header = {'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36 RuxitSynthetic/1.0 v7576960906 t38550 ath9b965f92 altpub cvcv=2'}

response = requests.get(url, headers=header)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

print()
print(soup.title.text, 'lxml')
print()

top_rest = soup.find('div', class_="col-sm-9 col-xs-12 tucal-canvas")
#print(top_rest)
list_tr = top_rest.find_all('div',class_="row")
for tr in list_tr:
    name = tr.find('table',class_="ohne zeile").text
    print(name)
# Out:
# Vorträge | Sonstiges | Professur Theoretische Informatik | Fakultät für Informatik | TU Chemnitz lxml
#
#
#
# Dr. Olaf Beyersdorff
# 			Parametrisierte Beweiskomplexität
# 			Donnerstag, 12. Juli 2012, 14:00 Uhr, Raum 1/336
#
#
# Peter Gmeiner
# 			Laplace Operatoren auf Hypergraphen
# 			Donnerstag, 24. Mai 2012, 10:45 Uhr, Raum 1/336
#
#
# Dr. Jochen Messner
# 			Das Lovász Local Lemma für SAT
# 			Dienstag, 15. November 2011, 14:00 Uhr, Raum 1/336
#
#
# Prof. Dr. Stephan Waack
# 			Eine Verallgemeinerung des klassischen Modells des PAC-Lernens mit Rauschen auf der Klassifikation und seine Anwendung in Bio- und Wirtschaftsinformatik
# 			Montag, 15. November 2010, 15:00 Uhr, Raum 1/336
#
#
# Prof. Dr. Dieter Kratsch
# 			Exact Exponential Algorithms
# 			Montag, 25. Oktober 2010, 15:00 Uhr, Raum 1/336
#
#
# Marc Dietzschkau
# 			Spektrale Partitionierung bipartiter Graphen
# 			Mittwoch, 17.09.2008, 11:00, Raum 1/346
#
#
# Steffen Riediger
# 			Schnelle Partitionierung von real-world- und Zufallsgraphen.
# 			Montag, 25.02.2008, 15:00, Raum 1/346
#
#
# Dr. Walter Guttmann
# Anordungsprobleme mit Einschränkungen
# 			Dienstag, 19.02.2008, 10:00, Raum 1/336
#
#
# Marc Dietzschkau
# 			Finden von eingepflanzten Cliquen in zufälligen Graphen
# 			Mittwoch, 23.01.2008, 14:30, Raum 1/232
#
#
# Prof. Dr. Petra Berenbrink
# A Sublinear-Time Approximation Scheme for Bin Packing
# 			Dienstag, 11.12.2007, 15:00, Raum 1/336
#
#
# Frank Fischer
# 			Effizientes Finden kleiner unabhängiger Mengen in zufälligen Graphen mit gegebener erwarteter Gradsequenz
# 			Donnerstag, 05.07.2007, 13:00, Raum 1/219
#
#
# Sebastian Dörn
# Quantum Query Komplexität von algebraischen Eigenschaften
# 			Mittwoch, 23. Mai 2007, 14:00 Raum 1/336
#
#
# André Lanka
# 			Spektrale Partitionierung zufälliger Graphen mit vorgegebener erwarteter Gradsequenz
# 			Freitag, 27.04.2007, 11:30 Raum 1/346
#
#
# Steffen Riediger
# 			Implementierung eines Algorithmus zur Partitionierung von Graphen
# 			Freitag, 30.03.2006, 11:30, Raum 1/346
#
#
# Markus John
# 			Grenzen von Algorithmen zur Exploration sehr großer Graphen
# 			Freitag, 06.10.2006, 14:00, Raum 1/346
#
#
# Christian Siebert
# 			The Quadratic Sieve Factoring Algorithm
# 			Donnerstag, 02.02.2006, 17:15, Raum 1/346
#
#
# Prof. Dr. Andreas Goerdt
# 			Grundlagen des Quantencomputing
# 			Donnerstag, 26.01.2006, 17:15, Raum 1/346
#
#
# Frank Fischer
# 			Ein auf dem longcode basierender Verifizierer Teil 2
# 			Dienstag, 24.01.2006, 15:00, Raum 1/346
#
#
# Frank Fischer
# 			Ein auf dem longcode basierender Verifizierer Teil 1
# 			Donnerstag, 19.01.2006, 17:15, Raum 1/346
#
#
# Markus John
# 			Implementierung und Evaluierung eines Algorithmus zur Exploration sehr großer Graphen.
# 			Freitag, 09.12.2005, 15:30, Raum 1/346
#
#
# Sascha Neupert
# 			Lineare Algebra und Erfüllbarkeitsalgorithmen für zufällige Formeln
# 			Freitag, 01.07.2005, 11:00, Raum 1/336
#
#
# Michael Auerbach
# 			Eine untere Schranke an die Approximationsgüte von Vertex Cover in 4-uniformen Hypergraphen
# 			Donnerstag, 03.02.2005, 15:30, Raum 1/201
#
#
# Prof. Dr. Ludek Kucera
# 			Low-degree connectivity in ad-hoc networks
# 			Dienstag, 14.12.2004, 14.30 Uhr, Raum 1/336
#
#
# Frank Schädlich
# 			Effizientes Verifizieren co-NP-vollständiger Probleme am Beispiel zufälliger 4-SAT-Formeln und uniformer Hypergraphen
# 			Mittwoch, 30.06.2004, 14:00, Raum 1/336
#
#
# Dr. Jan Johannsen
# 			Vollständige Erfüllbarkeitsprobleme für LogSpace
# 			Montag, 2.2.2004, 15.00 Uhr, Raum 1/336

# %%
from bs4 import BeautifulSoup
import requests
url = 'https://vsr.informatik.tu-chemnitz.de/about/people/'
header = {'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36 RuxitSynthetic/1.0 v7576960906 t38550 ath9b965f92 altpub cvcv=2'}

response = requests.get(url, headers=header)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

print()
print(soup.title.text)
print()

top_rest = soup.find('div', class_="tab-content")
#print(top_rest)
list_tr = top_rest.find_all('div',class_="detail-box")
for tr in list_tr:
    name = tr.find('div',class_="details").text
    print(name)
# Out:
# Distributed and Self-organizing Systems (VSR)
#     : About VSR
#     : People
#
#
#
#
#
#
#                                         Room: 1/B319
#
#
#
#
#                                         Phone: work+49 371 531 25530
#
#
#
#
#                                         Fax: workFax+49 371 531 25539
#
#
#
#
#                                         Email: workgaedke@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B318
#
#
#
#
#                                         Phone: work+49 371 531 37926
#
#
#
#
#                                         Email: workdajana.herklotz@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B204
#
#
#
#
#                                         Phone: work+49 371 531 32861
#
#
#
#
#                                         Fax: workFax+49 371 531 8 32861
#
#
#
#
#                                         Email: worksebastian.heil@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Phone: work+49 371 531-39156
#
#
#
#
#                                         Email: workmaik.benndorf@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Phone: work+49 351 211 87 113
#
#
#
#
#                                         Email: workeduard.daoud@s2016.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B204
#
#
#
#
#                                         Phone: work+49 371 531 35747
#
#
#
#
#                                         Fax: workFax+49 371 531 8 35747
#
#
#
#
#                                         Email: workchristoph.goepfert@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B203
#
#
#
#
#                                         Phone: work+49 371 531 30469
#
#
#
#
#                                         Fax: workFax+49 371 531 8 30469
#
#
#
#
#                                         Email: workandre.langer@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B203
#
#
#
#
#                                         Phone: work+49 371 531 30389
#
#
#
#
#                                         Fax: workFax+49 371 531 8 30389
#
#
#
#
#                                         Email: workmahda.noura@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Phone: work+49 3581 7671 211
#
#
#
#
#                                         Fax: workFax+49 3581 7671 293
#
#
#
#
#                                         Email: worka.schulz@hszg.de
#
#
#
#
#
#
#                                         Room: 1/B204
#
#
#
#
#                                         Phone: work+49 371 531 31233
#
#
#
#
#                                         Fax: workFax+49 371 531 8 31233
#
#
#
#
#                                         Email: workvalentin.siegert@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B204B
#
#
#
#
#                                         Phone: work+49 371 531 31384
#
#
#
#
#                                         Fax: workFax+49 371 531 8 31384
#
#
#
#
#                                         Email: worksontag@mathematik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Phone: work+49 3581 7671 251
#
#
#
#
#                                         Fax: workFax+49 3581 7671 293
#
#
#
#
#                                         Email: workm.ullrich@hszg.de
#
#
#
#
#
#
#                                         Room: 1/B203
#
#
#
#
#                                         Phone: work+49 371 531 36569
#
#
#
#
#                                         Fax: workFax+49 371 531 8 36569
#
#
#
#
#                                         Email: workdang.vu-nguyen-hai@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B204
#
#
#
#
#                                         Phone: work+49 371 531 31353
#
#
#
#
#                                         Fax: workFax+49 371 531 9 31353
#
#
#
#
#                                         Email: workbahareh.zarei@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B204
#
#
#
#
#                                         Phone: work+49 371 531-32100
#
#
#
#
#                                         Fax: workFax+49 371 531-832100
#
#
#
#
#                                         Email: workverena.traubinger@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workshovra.das@s2018.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workila.gautam@phil.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workdirk.leichsenring@s2009.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workviet-hung.nguyen@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workpham-tuan-khanh.nguyen@s2018.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workaaditya.prakash@s2017.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workkurt.roscher@s2018.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: worklucas.schroeder@s2017.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: worklukas.wegent@s2017.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B319
#
#
#
#
#                                         Phone: work+49 371 531 25530
#
#
#
#
#                                         Fax: workFax+49 371 531 25539
#
#
#
#
#                                         Email: workgaedke@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B318
#
#
#
#
#                                         Phone: work+49 371 531 37926
#
#
#
#
#                                         Email: workdajana.herklotz@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B204
#
#
#
#
#                                         Phone: work+49 371 531 32861
#
#
#
#
#                                         Fax: workFax+49 371 531 8 32861
#
#
#
#
#                                         Email: worksebastian.heil@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Phone: work+49 371 531-39156
#
#
#
#
#                                         Email: workmaik.benndorf@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Phone: work+49 351 211 87 113
#
#
#
#
#                                         Email: workeduard.daoud@s2016.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B204
#
#
#
#
#                                         Phone: work+49 371 531 35747
#
#
#
#
#                                         Fax: workFax+49 371 531 8 35747
#
#
#
#
#                                         Email: workchristoph.goepfert@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B203
#
#
#
#
#                                         Phone: work+49 371 531 30469
#
#
#
#
#                                         Fax: workFax+49 371 531 8 30469
#
#
#
#
#                                         Email: workandre.langer@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B203
#
#
#
#
#                                         Phone: work+49 371 531 30389
#
#
#
#
#                                         Fax: workFax+49 371 531 8 30389
#
#
#
#
#                                         Email: workmahda.noura@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Phone: work+49 3581 7671 211
#
#
#
#
#                                         Fax: workFax+49 3581 7671 293
#
#
#
#
#                                         Email: worka.schulz@hszg.de
#
#
#
#
#
#
#                                         Room: 1/B204
#
#
#
#
#                                         Phone: work+49 371 531 31233
#
#
#
#
#                                         Fax: workFax+49 371 531 8 31233
#
#
#
#
#                                         Email: workvalentin.siegert@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B204B
#
#
#
#
#                                         Phone: work+49 371 531 31384
#
#
#
#
#                                         Fax: workFax+49 371 531 8 31384
#
#
#
#
#                                         Email: worksontag@mathematik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Phone: work+49 3581 7671 251
#
#
#
#
#                                         Fax: workFax+49 3581 7671 293
#
#
#
#
#                                         Email: workm.ullrich@hszg.de
#
#
#
#
#
#
#                                         Room: 1/B203
#
#
#
#
#                                         Phone: work+49 371 531 36569
#
#
#
#
#                                         Fax: workFax+49 371 531 8 36569
#
#
#
#
#                                         Email: workdang.vu-nguyen-hai@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B204
#
#
#
#
#                                         Phone: work+49 371 531 31353
#
#
#
#
#                                         Fax: workFax+49 371 531 9 31353
#
#
#
#
#                                         Email: workbahareh.zarei@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Room: 1/B204
#
#
#
#
#                                         Phone: work+49 371 531-32100
#
#
#
#
#                                         Fax: workFax+49 371 531-832100
#
#
#
#
#                                         Email: workverena.traubinger@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workshovra.das@s2018.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workila.gautam@phil.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workdirk.leichsenring@s2009.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workviet-hung.nguyen@informatik.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workpham-tuan-khanh.nguyen@s2018.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workaaditya.prakash@s2017.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: workkurt.roscher@s2018.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: worklucas.schroeder@s2017.tu-chemnitz.de
#
#
#
#
#
#
#                                         Email: worklukas.wegent@s2017.tu-chemnitz.de
